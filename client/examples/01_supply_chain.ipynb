# %% [markdown]
# # Supply Chain Network
#
# Multi-tier supply chain with factories, distributors, and retailers.

# %%
from graphbridge import GraphBridge
from graphbridge.datasets import make_supply_chain

# %%
gb = GraphBridge(frontend_port=5173)
gb.health()
# Out:
# True

# %%
G = make_supply_chain()
print(f"Nodes: {G.number_of_nodes()}, Edges: {G.number_of_edges()}")
# Out:
# Nodes: 48, Edges: 121

# %%
from collections import Counter
Counter(G.nodes[n]["label"] for n in G.nodes())
# Out:
# Counter({'retailer': 26, 'distributor': 14, 'factory': 8})

# %%
gb.load(G)
gb.open()

# %%
gb.get_patterns()
# Out:
# []
