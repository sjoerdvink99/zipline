# %% [markdown]
# # BRON Threat Intelligence
#
# CVEs, CWEs, CAPECs, and MITRE ATT&CK techniques/tactics.
#
# Requires `data/BRON.json`.

# %%
from graphbridge import GraphBridge
from graphbridge.datasets import load_bron

# %%
gb = GraphBridge(frontend_port=5173)
gb.health()

# %%
G = load_bron(max_cves=300)
if G:
    print(f"Nodes: {G.number_of_nodes()}, Edges: {G.number_of_edges()}")

# %%
if G:
    from collections import Counter
    Counter(G.nodes[n]["label"] for n in G.nodes())

# %%
if G:
    gb.load(G)
    gb.open()

# %%
gb.get_patterns()
